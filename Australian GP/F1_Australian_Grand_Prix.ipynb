# %% [markdown]
# # Set Up

# %%
# !pip install pyergast
# !pip install gmplot
# Out:
# Collecting pyergast
#   Downloading pyErgast-0.1.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: pandas<2.0.0,>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from pyergast) (1.5.3)
# Requirement already satisfied: requests<3.0.0,>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from pyergast) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.1.5->pyergast) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.1.5->pyergast) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.1.5->pyergast) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.25.0->pyergast) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.25.0->pyergast) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.25.0->pyergast) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.25.0->pyergast) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.1.5->pyergast) (1.16.0)
# Installing collected packages: pyergast
# Successfully installed pyergast-0.1.0
# Collecting gmplot
#   Downloading gmplot-1.4.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.7/164.7 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from gmplot) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->gmplot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->gmplot) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->gmplot) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->gmplot) (2024.2.2)
# Installing collected packages: gmplot
# Successfully installed gmplot-1.4.1

# %%
import numpy as np
import pandas as pd
import datetime
from datetime import date
import os
import seaborn as sns
from IPython.display import Markdown as md
import matplotlib.pyplot as plt
import plotly.express as px
from scipy import stats
import plotly.graph_objects as go
pd.set_option('display.precision', 1)
from pyergast import pyergast
import requests
from plotly.offline import init_notebook_mode, iplot

# %%
def constructor_standings(year=None, race=None):
    if year and race:
        assert year >= 1958, 'Constructor standings only available starting 1958'
        url = 'http://ergast.com/api/f1/{}/{}/constructorStandings.json?limit=1000'.format(year, race)
    elif year:
        assert year >= 1958, 'Constructor standings only available starting 1958'
        url = 'http://ergast.com/api/f1/{}/constructorStandings.json?limit=1000'.format(year, race)
    else:
        url = 'http://ergast.com/api/f1/current/constructorStandings.json?limit=1000'

    r = requests.get(url)
    assert r.status_code == 200, 'Cannot connect to Ergast API. Check your inputs.'
    output = r.json()
    try:
        constructorStandings = output['MRData']['StandingsTable']['StandingsLists'][0]['ConstructorStandings']
    except:
        return pd.DataFrame()

    for constructor in constructorStandings:
        constructor['constructorID'] = constructor['Constructor']['constructorId']
        constructor['name'] = constructor['Constructor']['name']
        constructor['nationality'] = constructor['Constructor']['nationality']
        del constructor['Constructor']

    return pd.DataFrame(constructorStandings)

# %%
def get_pit_stops(year=None, race=None):
    """
    """
    if year and race:
        url = 'http://ergast.com/api/f1/{}/{}/pitstops.json?limit=1000'.format(year, race)
    r = requests.get(url)

    assert r.status_code == 200, 'Cannot connect to Ergast API'
    drivers = r.json()
    try:
        result = pd.DataFrame(drivers["MRData"]["RaceTable"]["Races"][0]["PitStops"])
    except:
        return pd.DataFrame()

    return result

# %%
def get_round(year=None, race=None):
    """
    """
    if year and race:
        url = 'http://ergast.com/api/f1/{}/{}/pitstops.json?limit=1000'.format(year, race)
    r = requests.get(url)

    assert r.status_code == 200, 'Cannot connect to Ergast API'
    drivers = r.json()
    try:
        result = pd.DataFrame(drivers["MRData"]["RaceTable"]["Races"][0]["PitStops"])
    except:
        return pd.DataFrame()

    return result

# %%
def get_lap_times(year=None, race=None):
    """
    """
    if year and race:
        url = 'http://ergast.com/api/f1/{}/{}/laps.json?limit=1000'.format(year, race)
    r = requests.get(url)

    assert r.status_code == 200, 'Cannot connect to Ergast API'
    drivers = r.json()
    try:
        result = pd.DataFrame(drivers["MRData"]["RaceTable"]["Races"][0]["Laps"])
    except:
        return pd.DataFrame()
    lap_df = pd.DataFrame()
    for lap in result.number.unique():
        temp_df = pd.DataFrame(result[result['number'] == lap].Timings.iloc[0])
        temp_df['lap'] = lap
        lap_df = pd.concat([lap_df, temp_df], ignore_index=True, axis=0)

    return lap_df

# %%
def get_last_round():
    """
    """
    url = 'http://ergast.com/api/f1/current/last/results.json?limit=1000'
    r = requests.get(url)

    assert r.status_code == 200, 'Cannot connect to Ergast API'
    drivers = r.json()
    try:
        result = drivers["MRData"]["RaceTable"]["round"]
    except:
        return pd.DataFrame()


    return int(result)

# %%
def get_sprint_results(year=None, race=None):
    """
    Get results of sprint, return empty dataframe if no sprint results available
    """
    if year and race:
        url = f'http://ergast.com/api/f1/{year}/{race}/sprint.json?limit=1000'
    r = requests.get(url)

    assert r.status_code == 200, 'Cannot connect to Ergast API'
    drivers = r.json()
    try:
        result = pd.DataFrame(drivers["MRData"]["RaceTable"]["Races"][0]["SprintResults"])
        result['driverID'] = result['Driver'].apply(lambda x: x['driverId'])
        result['Driver'] = result['Driver'].apply(lambda x: x['code'])
        result['constructorId'] = result['Constructor'].apply(lambda x: x['constructorId'])
    except:
        return pd.DataFrame()

    return result

# %%
#DATA CLEANING
##INITIAL PARAMETERS
my_date = date.today()
year, week_num, day_of_week = my_date.isocalendar()
race = get_last_round()

#RACE RESULTS
race_result = pyergast.get_race_result()
race_result['points'] = race_result.points.astype(float)
circuits = pyergast.get_circuits()

#CONSTRUCTORS
constructor_overall = constructor_standings(year=year)
const_ov_emp = constructor_overall.empty
if not const_ov_emp:
    constructor_overall['points'] = constructor_overall.points.astype(float)
constructor_results = constructor_standings(year=year, race=race)
const_re_emp = constructor_results.empty
if not const_re_emp:
    constructor_results['points'] = constructor_results.points.astype(float)
constructors = pyergast.get_constructors()

#DRIVERS
drivers = pyergast.get_drivers(year=year)
drivers_2 = pd.read_csv('./drivers.csv')
drivers_2 ['Driver'] = drivers_2['code']
drivers_2['driverID'] = drivers_2['driverRef']
drivers['driverID'] = drivers['driverId']
drivers_full = drivers.merge(drivers_2, on='driverID', how='left', suffixes=('_1', '_2'))
driver_standings = pyergast.driver_standings()

#LAPS
lap_times = get_lap_times(year, race)
lap_tim_emp = lap_times.empty
if not lap_tim_emp:
    lap_times['driverID'] = lap_times['driverId']
    lap_times['lap'] = lap_times['lap'].astype(int)

#PIT STOPS
pit_stops = get_pit_stops(year, race)
pit_stop_emp = pit_stops.empty
if not pit_stop_emp:
    pit_stops['driverID'] = pit_stops['driverId']

#QUALIFYING
qualifying = pyergast.get_qualifying_result()

#SPRINT RESULTS
sprint_results = get_sprint_results(year=year, race=race)
SPRINT_EMPTY = sprint_results.empty

#SCHEDULE
schedule = pyergast.get_schedule()
schedule['round'] = schedule['round'].astype(float)

# %%
## uncomment to see the data-object values.
# my_date
# race
race_result
# circuits
# constructors
# driver_standings
# lap_times
# pit_stops
# qualifying
# sprint_results
# schedule
# Out:
#    number position positionText grid  points         driverID  \
# 0      55        1            1    2    25.0            sainz
# 1      16        2            2    4    19.0          leclerc
# 2       4        3            3    3    15.0           norris
# 3      81        4            4    5    12.0          piastri
# 4      11        5            5    6    10.0            perez
# 5      18        6            6    9     8.0           stroll
# 6      22        7            7    8     6.0          tsunoda
# 7      14        8            8   10     4.0           alonso
# 8      27        9            9   16     2.0       hulkenberg
# 9      20       10           10   14     1.0  kevin_magnussen
# 10     23       11           11   12     0.0            albon
# 11      3       12           12   18     0.0        ricciardo
# 12     10       13           13   17     0.0            gasly
# 13     77       14           14   13     0.0           bottas
# 14     24       15           15   19     0.0             zhou
# 15     31       16           16   15     0.0             ocon
# 16     63       17           17    7     0.0          russell
# 17     44       18            R   11     0.0         hamilton
# 18      1       19            R    1     0.0   max_verstappen
#
#               driver nationality constructorID     constructor laps    status  \
# 0       Carlos Sainz     Spanish       ferrari         Ferrari   58  Finished
# 1    Charles Leclerc  Monegasque       ferrari         Ferrari   58  Finished
# 2       Lando Norris     British       mclaren         McLaren   58  Finished
# 3      Oscar Piastri  Australian       mclaren         McLaren   58  Finished
# 4       Sergio Pérez     Mexican      red_bull        Red Bull   58  Finished
# 5       Lance Stroll    Canadian  aston_martin    Aston Martin   58  Finished
# 6       Yuki Tsunoda    Japanese            rb      RB F1 Team   58  Finished
# 7    Fernando Alonso     Spanish  aston_martin    Aston Martin   58  Finished
# 8    Nico Hülkenberg      German          haas    Haas F1 Team   58  Finished
# 9    Kevin Magnussen      Danish          haas    Haas F1 Team   57    +1 Lap
# 10   Alexander Albon        Thai      williams        Williams   57    +1 Lap
# 11  Daniel Ricciardo  Australian            rb      RB F1 Team   57    +1 Lap
# 12      Pierre Gasly      French        alpine  Alpine F1 Team   57    +1 Lap
# 13   Valtteri Bottas     Finnish        sauber          Sauber   57    +1 Lap
# 14       Guanyu Zhou     Chinese        sauber          Sauber   57    +1 Lap
# 15      Esteban Ocon      French        alpine  Alpine F1 Team   57    +1 Lap
# 16    George Russell     British      mercedes        Mercedes   56  Accident
# 17    Lewis Hamilton     British      mercedes        Mercedes   15    Engine
# 18    Max Verstappen       Dutch      red_bull        Red Bull    3    Brakes
#
#                                             Time
# 0   {'millis': '4826843', 'time': '1:20:26.843'}
# 1        {'millis': '4829209', 'time': '+2.366'}
# 2        {'millis': '4832747', 'time': '+5.904'}
# 3       {'millis': '4862613', 'time': '+35.770'}
# 4       {'millis': '4883152', 'time': '+56.309'}
# 5     {'millis': '4920065', 'time': '+1:33.222'}
# 6     {'millis': '4922444', 'time': '+1:35.601'}
# 7     {'millis': '4927835', 'time': '+1:40.992'}
# 8     {'millis': '4931396', 'time': '+1:44.553'}
# 9                                            NaN
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN

# %%
#Helpers
def get_sec(time_str):
    """Get seconds from time."""
    if (time_str != '\\N' or not time_str):
        m, s = str(time_str).split(':')
        return float(m) * 60 + float(s)

def get_sec3(time_str):
    """Get seconds from time."""
    if (time_str != '\\N' or not time_str):
        h, m, s = str(time_str).split(':')
        return float(h)*3600 + float(m) * 60 + float(s)

def time_to_seconds(time_str):
    if (time_str != '\\N' or not time_str):
        time_str = str(time_str)
        if time_str == '':
            return None
        parts = time_str.split(':')
        if len(parts) == 1:
            # s.mill format
            return float(parts[0])
        elif len(parts) == 2:
            # minute:seconds.milliseconds format
            minutes = int(parts[0])
            seconds = float(parts[1])
            return minutes * 60 + seconds
        elif len(parts) == 3:
            # hour:minute:seconds.milliseconds format
            hours = int(parts[0])
            minutes = int(parts[1])
            seconds = float(parts[2])
            return hours * 3600 + minutes * 60 + seconds
        else:
            raise ValueError("Invalid time format")

def convert_time_end(row):
    return row['time_date'] + datetime.timedelta(0, row['duration'])

#Colors
constructor_color_map = {
        'Williams': '#00A0DE',
        'Sauber': '#A42134',
        'RB F1 Team': '#20394C',
        'Red Bull': '#000B8D',
        'Mercedes': '#00A19B',
        'Haas F1 Team': '#E6002B',
          'Aston Martin': '#002420',
          'Ferrari': '#EF1A2D',
          'Alpine F1 Team': '#2173B8',
        'McLaren': '#FF8000'
}

def build_driver_col_map(row):
    const = row['constructor']

    color = constructor_color_map[const]
    row['driverColor'] = color
    row['Driver'] = drivers_full.loc[drivers_full['driverID'] == row['driverID']]['Driver'].values[0]
    return row

race_result = race_result.apply(build_driver_col_map, axis=1)

unique_df = race_result.drop_duplicates(subset='Driver', keep='last')
color_map = dict(zip(unique_df['Driver'], unique_df['driverColor']))

race_result.drop(columns=['Driver'], inplace=True)

# %%
# DATA CLEANING
if not lap_tim_emp:
    lap_times['duration'] = lap_times['time'].apply(get_sec)
    lap_times['red_flag'] = 0
    lap_times.loc[lap_times['duration'] > 300.0, 'red_flag'] = 1


current_circuit = schedule[schedule['round'] == race].circuitID.values[0]
current_race_name = schedule[schedule['round'] == race].circuitName.values[0]
current_race_date = schedule[schedule['round'] == race].date.values[0]


#DRIVER/LAP
if not lap_tim_emp:
    lap_driver = lap_times.merge(drivers_full, on='driverID', how='left', suffixes=('_1', '_2'))
    lap_driver['lap'] = lap_driver.lap.astype(float)
    lap_driver = lap_driver[lap_driver['red_flag'] == 0].copy()
    lap_driver_no = lap_driver[(stats.zscore(lap_driver['duration'])) <1]
    lap_driver['position'] = lap_driver['position'].astype(int)


# #RESULTS
# num_laps = max(race_result['laps'].astype(int))
# merged = race_result.merge(drivers_full, on='driverID', how='left', suffixes=('_1', '_2'))
# res_race_laps = merged.copy()
# res_race_laps['laps'] = 0
# reduced = res_race_laps[['laps', 'grid', 'Driver']]
# reduced.columns = ['laps', 'position', 'Driver']
# reduced_res = pd.concat([reduced, merged[['laps', 'position', 'Driver']]], axis=0)
# reduced_res['laps'] = reduced_res['laps'].astype(int)
# reduced_res['last_lap'] = 0
# reduced_res['Driver'] = reduced_res['Driver'].astype(str)
# ##Add flag for non-finishers
# for driver in color_map.keys():
#     temp = reduced_res[reduced_res['Driver'] == driver]
#     max_driver_laps = max(temp['laps'])
#     if max_driver_laps < num_laps:
#         #This driver didn't finish
#         reduced_res.loc[(reduced_res['Driver'] == driver) & (reduced_res['laps'] == max_driver_laps), 'last_lap'] = 1

#CONSTRUCTORS
constructor_results = pd.DataFrame()
for i in range(1, race+1):
    if i == 1:
        constructor_results = constructor_standings(year=year, race=i)
        constructor_results['race'] = i
    else:
        temp = constructor_standings(year=year, race=i)
        temp['race'] = i
        constructor_results = pd.concat([constructor_results, temp], axis=0)
constructor_results['points'] = constructor_results['points'].astype(float)



track = circuits[circuits['circuitId'] == current_circuit]
track_lat = track['Latitude'].values[0]
track_lng = track['Longtitude'].values[0]


#PODIIUM
res_race_lap_status_pod = race_result[race_result['position'] != '\\N'].copy()
res_race_lap_status_pod = res_race_lap_status_pod.merge(drivers_full, on='driverID', how='left', suffixes=('_1', '_2'))
res_race_lap_status_pod['position'] = res_race_lap_status_pod['position'].astype(int)
res_race_lap_status_pod = res_race_lap_status_pod.sort_values(by='position')


#PIT STOPS
if not pit_stop_emp:
    pit_stops['duration'] = pit_stops['duration'].apply(lambda x: time_to_seconds(x))
    pit_stops['duration'] = pit_stops['duration'].astype(float)
    pit_stops['red_flag'] = (pit_stops['duration'] > 600.0).astype(int)
##PIT STOP DURATIONS
    pit_stops['time_stamp'] = current_race_date + ' ' + pit_stops['time']
    pit_stops['time_date'] = pd.to_datetime(pit_stops['time_stamp'])
    pit_stops['time_end_date'] = pit_stops.apply(lambda x: convert_time_end(x), axis=1)
#MERGE WITH DRIVERS
    driver_group = pd.DataFrame()
    pit_stops = pit_stops.merge(drivers_full, on='driverID', how='left', suffixes=('_1', '_2'))
    mean = pit_stops[pit_stops['red_flag'] == 0].groupby(['Driver'])['duration'].mean()
    mini = pit_stops[pit_stops['red_flag'] == 0].groupby(['Driver'])['duration'].min()
    maxi = pit_stops[pit_stops['red_flag'] == 0].groupby(['Driver'])['duration'].max()
    driver_group['mean'] = mean
    driver_group['max'] = maxi
    driver_group['min'] = mini
    driver_group = driver_group.sort_values(by="max")
    driver_group['Driver'] = maxi.index

# QUALIFYING & FINISHING
qualifying = qualifying.fillna('\\N')
qualifying['q1_dur'] = qualifying['Q1'].apply(time_to_seconds)
qualifying['q2_dur'] = qualifying['Q2'].apply(time_to_seconds)
qualifying['q3_dur'] = qualifying['Q3'].apply(time_to_seconds)
qualifying['max_time'] = qualifying.apply(lambda x: max(x['q1_dur'], x['q2_dur'], x['q3_dur']), axis=1)
qualifying['min_time'] = qualifying.apply(lambda x: min(x['q1_dur'], x['q2_dur'], x['q3_dur']), axis=1)
max_time = max(qualifying['max_time']) + 1
min_time = min(qualifying['min_time']) - 1
if max_time > (min_time+15):
    max_time = min_time+15
qualifying = qualifying.merge(drivers_full, on='driverID', how='left', suffixes=('_1', '_2'))

#SPRINT
if not SPRINT_EMPTY:
    sprint_results['points'] = sprint_results['points'].astype(float)
    sprint_results['position'] = sprint_results['position'].astype(int)
    sprint_results['grid'] = sprint_results['grid'].astype(int)


    num_sprint_laps = max(sprint_results['laps'].astype(int))
    #merged = race_result.merge(drivers_full, on='driverID', how='left', suffixes=('_1', '_2'))
    sp_res_race_laps = sprint_results.copy()
    sp_res_race_laps['laps'] = 0
    sp_reduced = sp_res_race_laps[['laps', 'grid', 'Driver']]
    sp_reduced.columns = ['laps', 'position', 'Driver']
    sp_reduced_res = pd.concat([sp_reduced, sprint_results[['laps', 'position', 'Driver']]], axis=0)
    sp_reduced_res['laps'] = sp_reduced_res['laps'].astype(int)
    sp_reduced_res['last_lap'] = 0
    sp_reduced_res['Driver'] = sp_reduced_res['Driver'].astype(str)
    for driver in color_map.keys():
        temp = sp_reduced_res[sp_reduced_res['Driver'] == driver]
        max_driver_laps = max(temp['laps'])
        if max_driver_laps < num_sprint_laps:
            #This driver didn't finish
            sp_reduced_res.loc[(sp_reduced_res['Driver'] == driver) & (sp_reduced_res['laps'] == max_driver_laps), 'last_lap'] = 1

# %%
# Styling
def podium(styler):
    styler.set_caption("Podium Results")
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlOrRd")
    styler.hide_index()
   # styler.format({'points': "{.1f}"})
    return styler


def results_style(styler):
    styler.set_caption("Race Results")
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlOrRd")
    styler.hide_index()
    return styler

def sprint_results_style(styler):
    styler.set_caption("Sprint Results")
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="ag_Sunset")
    styler.hide_index()
    return styler

def driver_stand(styler):
    styler.set_caption("Driver Standings")
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlGnBu")
    styler.hide_index()
    return styler

def const_standings(styler):
    styler.set_caption("Constructor Standings")
    styler.background_gradient(axis=None, vmin=1, vmax=5, cmap="YlOrRd")
    styler.hide_index()
    return styler

# %% [markdown]
# # Analysis

# %%
fig = px.scatter_mapbox(track, lat="Latitude", lon="Longtitude",
                        color_discrete_sequence=["red"], zoom=12, height=300)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4f7d5d74-3bb7-4e30-be87-66224fb72b25" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f7d5d74-3bb7-4e30-be87-66224fb72b25")) {                    Plotly.newPlot(                        "4f7d5d74-3bb7-4e30-be87-66224fb72b25",                        [{"hovertemplate":"Latitude=%{lat}\u003cbr\u003eLongtitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":["-37.8497"],"legendgroup":"","lon":["144.968"],"marker":{"color":"red"},"mode":"markers","name":"","showlegend":false,"subplot":"mapbox","type":"scattermapbox"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}], ...

# %%
res_race_lap_status_pod[['Driver', 'grid', 'position', 'points']].iloc[:3].style.pipe(podium)
# Out:
# <ipython-input-13-956f3cd6c2f3>:5: FutureWarning:
#
# this method is deprecated in favour of `Styler.hide(axis="index")`
# <style type="text/css">
# #T_5202d_row0_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_5202d_row0_col3, #T_5202d_row1_col3, #T_5202d_row2_col3 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_5202d_row1_col2 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_5202d_row2_col2 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5202d" class="dataframe">
#   <caption>Podium Results</caption>
#   <thead>
#     <tr>
#       <th id="T_5202d_level0_col0" class="col_heading level0 col0" >Driver</th>
#       <th id="T_5202d_level0_col1" class="col_heading level0 col1" >grid</th>
#       <th id="T_5202d_level0_col2" class="col_heading level0 col2" >position</th>
#       <th id="T_5202d_level0_col3" class="col_heading level0 col3" >points</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5202d_row0_col0" class="data row0 col0" >SAI</td>
#       <td id="T_5202d_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_5202d_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_5202d_row0_col3" class="data row0 col3" >25.000000</td>
#     </tr>
#     <tr>
#       <td id="T_5202d_row1_col0" class="data row1 col0" >LEC</td>
#       <td id="T_5202d_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_5202d_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_5202d_row1_col3" class="data row1 col3" >19.000000</td>
#     </tr>
#     <tr>
#       <td id="T_5202d_row2_col0" class="data row2 col0" >NOR</td>
#       <td id="T_5202d_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_5202d_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_5202d_row2_col3" class="data row2 col3" >15.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
res_race_lap_status_pod[['Driver', 'grid', 'position', 'points', 'status']].style.pipe(results_style)
# Out:
# <ipython-input-13-956f3cd6c2f3>:13: FutureWarning:
#
# this method is deprecated in favour of `Styler.hide(axis="index")`
# <style type="text/css">
# #T_25a56_row0_col2, #T_25a56_row9_col3, #T_25a56_row10_col3, #T_25a56_row11_col3, #T_25a56_row12_col3, #T_25a56_row13_col3, #T_25a56_row14_col3, #T_25a56_row15_col3, #T_25a56_row16_col3, #T_25a56_row17_col3, #T_25a56_row18_col3 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_25a56_row0_col3, #T_25a56_row1_col3, #T_25a56_row2_col3, #T_25a56_row3_col3, #T_25a56_row4_col2, #T_25a56_row4_col3, #T_25a56_row5_col2, #T_25a56_row5_col3, #T_25a56_row6_col2, #T_25a56_row6_col3, #T_25a56_row7_col2, #T_25a56_row8_col2, #T_25a56_row9_col2, #T_25a56_row10_col2, #T_25a56_row11_col2, #T_25a56_row12_col2, #T_25a56_row13_col2, #T_25a56_row14_col2, #T_25a56_row15_col2, #T_25a56_row16_col2, #T_25a56_row17_col2, #T_25a56_row18_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_25a56_row1_col2, #T_25a56_row8_col3 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_25a56_row2_col2 {
#   background-color: #fd8c3c;
#   color: #f1f1f1;
# }
# #T_25a56_row3_col2, #T_25a56_row7_col3 {
#   background-color: #e2191c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_25a56" class="dataframe">
#   <caption>Race Results</caption>
#   <thead>
#     <tr>
#       <th id="T_25a56_level0_col0" class="col_heading level0 col0" >Driver</th>
#       <th id="T_25a56_level0_col1" class="col_heading level0 col1" >grid</th>
#       <th id="T_25a56_level0_col2" class="col_heading level0 col2" >position</th>
#       <th id="T_25a56_level0_col3" class="col_heading level0 col3" >points</th>
#       <th id="T_25a56_level0_col4" class="col_heading level0 col4" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_25a56_row0_col0" class="data row0 col0" >SAI</td>
#       <td id="T_25a56_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_25a56_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_25a56_row0_col3" class="data row0 col3" >25.000000</td>
#       <td id="T_25a56_row0_col4" class="data row0 col4" >Finished</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row1_col0" class="data row1 col0" >LEC</td>
#       <td id="T_25a56_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_25a56_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_25a56_row1_col3" class="data row1 col3" >19.000000</td>
#       <td id="T_25a56_row1_col4" class="data row1 col4" >Finished</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row2_col0" class="data row2 col0" >NOR</td>
#       <td id="T_25a56_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_25a56_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_25a56_row2_col3" class="data row2 col3" >15.000000</td>
#       <td id="T_25a56_row2_col4" class="data row2 col4" >Finished</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row3_col0" class="data row3 col0" >PIA</td>
#       <td id="T_25a56_row3_col1" class="data row3 col1" >5</td>
#       <td id="T_25a56_row3_col2" class="data row3 col2" >4</td>
#       <td id="T_25a56_row3_col3" class="data row3 col3" >12.000000</td>
#       <td id="T_25a56_row3_col4" class="data row3 col4" >Finished</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row4_col0" class="data row4 col0" >PER</td>
#       <td id="T_25a56_row4_col1" class="data row4 col1" >6</td>
#       <td id="T_25a56_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_25a56_row4_col3" class="data row4 col3" >10.000000</td>
#       <td id="T_25a56_row4_col4" class="data row4 col4" >Finished</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row5_col0" class="data row5 col0" >STR</td>
#       <td id="T_25a56_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_25a56_row5_col2" class="data row5 col2" >6</td>
#       <td id="T_25a56_row5_col3" class="data row5 col3" >8.000000</td>
#       <td id="T_25a56_row5_col4" class="data row5 col4" >Finished</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row6_col0" class="data row6 col0" >TSU</td>
#       <td id="T_25a56_row6_col1" class="data row6 col1" >8</td>
#       <td id="T_25a56_row6_col2" class="data row6 col2" >7</td>
#       <td id="T_25a56_row6_col3" class="data row6 col3" >6.000000</td>
#       <td id="T_25a56_row6_col4" class="data row6 col4" >Finished</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row7_col0" class="data row7 col0" >ALO</td>
#       <td id="T_25a56_row7_col1" class="data row7 col1" >10</td>
#       <td id="T_25a56_row7_col2" class="data row7 col2" >8</td>
#       <td id="T_25a56_row7_col3" class="data row7 col3" >4.000000</td>
#       <td id="T_25a56_row7_col4" class="data row7 col4" >Finished</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row8_col0" class="data row8 col0" >HUL</td>
#       <td id="T_25a56_row8_col1" class="data row8 col1" >16</td>
#       <td id="T_25a56_row8_col2" class="data row8 col2" >9</td>
#       <td id="T_25a56_row8_col3" class="data row8 col3" >2.000000</td>
#       <td id="T_25a56_row8_col4" class="data row8 col4" >Finished</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row9_col0" class="data row9 col0" >MAG</td>
#       <td id="T_25a56_row9_col1" class="data row9 col1" >14</td>
#       <td id="T_25a56_row9_col2" class="data row9 col2" >10</td>
#       <td id="T_25a56_row9_col3" class="data row9 col3" >1.000000</td>
#       <td id="T_25a56_row9_col4" class="data row9 col4" >+1 Lap</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row10_col0" class="data row10 col0" >ALB</td>
#       <td id="T_25a56_row10_col1" class="data row10 col1" >12</td>
#       <td id="T_25a56_row10_col2" class="data row10 col2" >11</td>
#       <td id="T_25a56_row10_col3" class="data row10 col3" >0.000000</td>
#       <td id="T_25a56_row10_col4" class="data row10 col4" >+1 Lap</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row11_col0" class="data row11 col0" >RIC</td>
#       <td id="T_25a56_row11_col1" class="data row11 col1" >18</td>
#       <td id="T_25a56_row11_col2" class="data row11 col2" >12</td>
#       <td id="T_25a56_row11_col3" class="data row11 col3" >0.000000</td>
#       <td id="T_25a56_row11_col4" class="data row11 col4" >+1 Lap</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row12_col0" class="data row12 col0" >GAS</td>
#       <td id="T_25a56_row12_col1" class="data row12 col1" >17</td>
#       <td id="T_25a56_row12_col2" class="data row12 col2" >13</td>
#       <td id="T_25a56_row12_col3" class="data row12 col3" >0.000000</td>
#       <td id="T_25a56_row12_col4" class="data row12 col4" >+1 Lap</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row13_col0" class="data row13 col0" >BOT</td>
#       <td id="T_25a56_row13_col1" class="data row13 col1" >13</td>
#       <td id="T_25a56_row13_col2" class="data row13 col2" >14</td>
#       <td id="T_25a56_row13_col3" class="data row13 col3" >0.000000</td>
#       <td id="T_25a56_row13_col4" class="data row13 col4" >+1 Lap</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row14_col0" class="data row14 col0" >ZHO</td>
#       <td id="T_25a56_row14_col1" class="data row14 col1" >19</td>
#       <td id="T_25a56_row14_col2" class="data row14 col2" >15</td>
#       <td id="T_25a56_row14_col3" class="data row14 col3" >0.000000</td>
#       <td id="T_25a56_row14_col4" class="data row14 col4" >+1 Lap</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row15_col0" class="data row15 col0" >OCO</td>
#       <td id="T_25a56_row15_col1" class="data row15 col1" >15</td>
#       <td id="T_25a56_row15_col2" class="data row15 col2" >16</td>
#       <td id="T_25a56_row15_col3" class="data row15 col3" >0.000000</td>
#       <td id="T_25a56_row15_col4" class="data row15 col4" >+1 Lap</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row16_col0" class="data row16 col0" >RUS</td>
#       <td id="T_25a56_row16_col1" class="data row16 col1" >7</td>
#       <td id="T_25a56_row16_col2" class="data row16 col2" >17</td>
#       <td id="T_25a56_row16_col3" class="data row16 col3" >0.000000</td>
#       <td id="T_25a56_row16_col4" class="data row16 col4" >Accident</td>
#     </tr>
#     <tr>
#       <td id="T_25a56_row17_col0" class="data row17 col0" >HAM</td>
#       <td id="T_25a56_row17_col1" class="data row17 col1" >11</td>
#       <td id="T_25a56_row17_col2" class="data row17 col2" >18</td>
#       <td id="T_25a56_row17_col3" class="data row17 col3" >0.000000</td>
#       <td id="T_25a

# %%
fig = go.Figure(layout_yaxis_range=[min_time, max_time])
fig.add_trace(go.Bar(
    x=qualifying['Driver'],
    y=qualifying['q1_dur'],
    name='Q1',
    marker_color='#94d2bd'
))
fig.add_trace(go.Bar(
    x=qualifying['Driver'],
    y=qualifying['q2_dur'],
    name='Q2',
    marker_color='#0a9396'
))
fig.add_trace(go.Bar(
    x=qualifying['Driver'],
    y=qualifying['q3_dur'],
    name='Q3',
    marker_color='#005f73'
))

fig.update_layout(barmode='group', xaxis_tickangle=-45)
fig.update_layout(title_text='<b>Qualifying Results</b>', titlefont = dict(
         family = 'Arial, sans-serif',
         size = 30
      ), title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="528e6ace-9ac6-4b95-9d7f-9c9128abc04a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("528e6ace-9ac6-4b95-9d7f-9c9128abc04a")) {                    Plotly.newPlot(                        "528e6ace-9ac6-4b95-9d7f-9c9128abc04a",                        [{"marker":{"color":"#94d2bd"},"name":"Q1","x":["VER","SAI","PER","NOR","LEC","PIA","RUS","TSU","STR","ALO","HAM","ALB","BOT","MAG","OCO","HUL","GAS","RIC","ZHO"],"y":[76.819,76.731,76.805,77.43,76.98400000000001,77.369,77.062,77.356,77.376,76.991,77.499,77.13,77.543,77.709,77.617,77.976,77.982,78.08500000000001,78.188],"type":"bar"},{"marker":{"color":"#0a9396"},"name":"Q2","x":["VER","SAI","PER","NOR","LEC","PIA","RUS","TSU","STR","ALO","HAM","ALB","BOT","MAG","OCO","HUL","GAS","RIC","ZHO"],"y":[76.387,76.189,76.631,76.75,76.304,76.601,76.901,76.791,76.78,76.71000000000001,76.96000000000001,77.167,77.34,77.42699999999999,77.697,null,null,null,null],"type":"bar"},{"marker":{"color":"#005f73"},"name":"Q3","x":["VER","SAI","PER","NOR","LEC","PIA","RUS","TSU","STR","ALO","HAM","ALB","BOT","MAG","OCO","HUL","GAS","RIC","ZHO"],"y":[75.91499999999999,76.185,76.274,76.315,76.435,76.572,76.724,76.788,77.072,77.55199999999999,null,null,null,null,null,null,null,null,null],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}]," ...

# %%
if not SPRINT_EMPTY:
    display(sprint_results[['Driver', 'grid', 'position', 'points', 'status']].style.pipe(sprint_results_style))

# %%
def multi_st_fin_spr_plot(names, addAll = True):
    fig = go.Figure()

    lap_driver_sf = sp_reduced_res[(sp_reduced_res['laps'] == 0) | (sp_reduced_res['laps'] == num_sprint_laps) | (sp_reduced_res['last_lap'] == 1)].copy()
    lap_driver_sf['position'] = lap_driver_sf['position'].astype(float)
    lap_driver_sf = lap_driver_sf.sort_values(by=['Driver'])

    df = px.data.gapminder().query("continent=='Oceania'")
    fig = px.line(lap_driver_sf, x="laps", y="position", color='Driver', color_discrete_map=color_map, title="Qualifying to Sprint Finish", labels={
    "position": "Start Position",
    "laps":"Lap (Start/Finish Only)"
    })
    fig.update_layout(title_text='<b>Qualifying To Sprint Finish</b>', titlefont = dict(
         family = 'Arial, sans-serif',
         size = 30
      ), title_x=0.5)


    button_all = dict(label = 'All',
                      method = 'update',
                      args = [{'visible': [True]*len(names),
                               'title': 'All',
                               'showlegend':True}])

    def create_layout_button(column):
        return dict(label = column,
                    method = 'update',
                    args = [{'visible': [c == column for c in names],
                             'title': column,
                             'showlegend': True}])

    fig.update_layout(
        updatemenus=[go.layout.Updatemenu(
            active = 0,
            buttons = ([button_all] * addAll) + [create_layout_button(column) for column in names]
            )
        ])

    fig.show()
if not SPRINT_EMPTY:
    mapping = list(color_map.keys())
    mapping.sort()
    multi_st_fin_spr_plot(mapping)

# %%
if not pit_stop_emp:
    fig = px.timeline(pit_stops[pit_stops['red_flag'] == 0], x_start="time_date", x_end="time_end_date", y="Driver", color='Driver', color_discrete_map=color_map)
    fig.update_layout(showlegend=False)
    fig.update_layout(title_text='<b>Pit Strategy</b>', titlefont = dict(
         family = 'Arial, sans-serif',
         size = 30
      ), title_x=0.5)
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="631f4089-02b4-4e96-9ab6-3789b2b72714" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("631f4089-02b4-4e96-9ab6-3789b2b72714")) {                    Plotly.newPlot(                        "631f4089-02b4-4e96-9ab6-3789b2b72714",                        [{"alignmentgroup":"True","base":["2024-03-24T15:10:25","2024-03-24T15:44:29"],"hovertemplate":"Driver=%{y}\u003cbr\u003etime_date=%{base}\u003cbr\u003etime_end_date=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RIC","marker":{"color":"#20394C","pattern":{"shape":""}},"name":"RIC","offsetgroup":"RIC","orientation":"h","showlegend":true,"textposition":"auto","x":[18265.0,17751.0],"xaxis":"x","y":["RIC","RIC"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["2024-03-24T15:11:45","2024-03-24T15:41:35"],"hovertemplate":"Driver=%{y}\u003cbr\u003etime_date=%{base}\u003cbr\u003etime_end_date=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ALB","marker":{"color":"#00A0DE","pattern":{"shape":""}},"name":"ALB","offsetgroup":"ALB","orientation":"h","showlegend":true,"textposition":"auto","x":[17755.0,17745.0],"xaxis":"x","y":["ALB","ALB"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["2024-03-24T15:11:49","2024-03-24T15:52:50"],"hovertemplate":"Driver=%{y}\u003cbr\u003etime_date=%{base}\u003cbr\u003etime_end_date=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ZHO","marker":{"color":"#A42134","pattern":{"shape":""}},"name":"ZHO","offsetgroup":"ZHO","orientation":"h","showlegend":true,"textposition":"auto","x":[19032.0,36866.0],"xaxis":"x","y":["ZHO","ZHO"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["2024-03-24T15:13:04"],"hovertemplate":"Driver=%{y}\u003cbr\u003etime_date=%{base}\u003cbr\u003etime_end_date=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HAM","marker":{"color":"#00A19B","pattern":{"shape":""}},"name":"HAM","offsetgroup":"HAM","orientation":"h","showlegend":true,"textposition":"auto","x":[17596.0],"xaxis":"x","y":["HAM"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["2024-03-24T15:13:08","2024-03-24T15:49:58"],"hovertemplate":"Driver=%{y}\u003cbr\u003etime_date=%{base}\u003cbr\u003etime_end_date=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MAG","marker":{"color":"#E6002B","pattern":{"shape":""}},"name":"MAG","offsetgroup":"MAG","orientation":"h","showlegend":true,"textposition":"auto","x":[18301.0,18151.0],"xaxis":"x","y":["MAG","MAG"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["2024-03-24T15:14:23","2024-03-24T16:06:07"],"hovertemplate":"Driver=%{y}\u003cbr\u003etime_date=%{base}\u003cbr\u003etime_end_date=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RUS","marker":{"color":"#00A19B","pattern":{"shape":""}},"name":"RUS","offsetgroup":"RUS","orientation":"h","showlegend":true,"textposition":"auto","x":[18046.0,17964.0],"xaxis":"x","y":["RUS","RUS"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["2024-03-24T15:14:26","2024-03-24T15:55:19"],"hovertemplate":"Driver=%{y}\u003cbr\u003etime_date=%{base}\u003cbr\u003etime_end_date=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"STR","marker":{"color":"#002420","pattern":{"shape":""}},"name":"STR","offsetgroup":"STR","orientation":"h","showlegend":true,"textposition":"auto","x":[17901.0,17977.0],"xaxis":"x","y":["STR","STR"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["2024-03-24T15:14:30","2024-03-24T15:54:30"],"hovertemplate":"Driver=%{y}\u003cbr\u003etime_date=%{base}\u003cbr\u003etime_end_date=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BOT","marker":{"color":"#A42134","pattern":{"shape":""}},"name":"BOT","offsetgroup ...

# %%
if pit_stop_emp:
    display(md(f"<h1 style='background:#FFF200;border:0; color:black;box-shadow: 10px 10px 5px 0px rgba(0,0,0,0.75);transform: rotateX(10deg);'><center style='color: black;'>No Pit Data Available From API</center></h1>"))
elif not pit_stops[pit_stops['red_flag'] == 1].empty:
    fig = px.timeline(pit_stops[pit_stops['red_flag'] == 1], x_start="time_date", x_end="time_end_date", y="Driver", color='Driver', color_discrete_map=color_map)
    fig.update_layout(showlegend=False)
    fig.update_layout(title_text='<b>Red Flag Stops</b>', titlefont = dict(
         family = 'Arial, sans-serif',
         size = 30
      ), title_x=0.5)
    fig.show()

# %%
if not pit_stop_emp:
    max_pit = max(driver_group['max']) + 1
    min_pit = min(driver_group['min']) - 1

    data = [
    go.Bar(y=driver_group['max'], x=driver_group.Driver, name='Max Pit', marker=dict(color='#9b2226')),
    go.Bar(y=driver_group['mean'], x=driver_group.Driver, name='Avg PIt', marker=dict(color='#e9d8a6')),
    go.Bar(y=driver_group['min'], x=driver_group.Driver, name='Min PIt', marker=dict(color='#005f73'))]

    layout = go.Layout(
    barmode='overlay',
    title="Pit Times",
    title_text='<b>Pit Stop Times</b>', titlefont = dict(
         family = 'Arial, sans-serif',
         size = 30
      ), title_x=0.5
    )

    fig = dict(data = data, layout = layout, layout_yaxis_range=[min_pit, max_pit])

    iplot(fig, show_link=False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="41ddbfad-76f0-4487-80f9-7a865901d7c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41ddbfad-76f0-4487-80f9-7a865901d7c9")) {                    Plotly.newPlot(                        "41ddbfad-76f0-4487-80f9-7a865901d7c9",                        [{"marker":{"color":"#9b2226"},"name":"Max Pit","x":["ALB","ALO","BOT","GAS","HAM","HUL","LEC","MAG","NOR","OCO","PER","PIA","RIC","RUS","SAI","STR","TSU","ZHO"],"y":[17.409,17.596,17.74,17.755,17.776,17.977,18.046,18.112,18.16,18.265,18.301,18.32,18.523,18.533,20.316,30.626,36.866,46.969],"type":"bar"},{"marker":{"color":"#e9d8a6"},"name":"Avg PIt","x":["ALB","ALO","BOT","GAS","HAM","HUL","LEC","MAG","NOR","OCO","PER","PIA","RIC","RUS","SAI","STR","TSU","ZHO"],"y":[17.3585,17.596,17.6695,17.75,17.7145,17.939,18.005,17.667,18.0775,18.008000000000003,18.226,18.2325,18.029,18.053,18.999,22.30666666666667,27.948999999999998,32.9535],"type":"bar"},{"marker":{"color":"#005f73"},"name":"Min PIt","x":["ALB","ALO","BOT","GAS","HAM","HUL","LEC","MAG","NOR","OCO","PER","PIA","RIC","RUS","SAI","STR","TSU","ZHO"],"y":[17.308,17.596,17.599,17.745,17.653,17.901,17.964,17.222,17.995,17.751,18.151,18.145,17.535,17.573,17.682,18.007,19.032,18.938],"type":"bar"}],                        {"barmode":"overlay","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7 ...

# %%
if not lap_tim_emp:
    fig = px.box(lap_driver_no, x="duration", y="Driver", color='Driver', points=False, color_discrete_map=color_map, labels={
    "code": "Driver",
    "duration":"Duration (Seconds, Outliers/Red Flags, Removed)"
    })
    fig.update_layout(showlegend=False)
    fig.update_layout(title_text='<b>Lap Times</b>', titlefont = dict(
         family = 'Arial, sans-serif',
         size = 30
      ), title_x=0.5)
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eabe2f86-849c-460e-bde3-e1728608a11c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eabe2f86-849c-460e-bde3-e1728608a11c")) {                    Plotly.newPlot(                        "eabe2f86-849c-460e-bde3-e1728608a11c",                        [{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Driver=%{y}\u003cbr\u003eDuration (Seconds, Outliers\u002fRed Flags, Removed)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"VER","marker":{"color":"#000B8D"},"name":"VER","notched":false,"offsetgroup":"VER","orientation":"h","showlegend":true,"x":[87.458,84.099,83.115],"x0":" ","xaxis":"x","y":["VER","VER","VER"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Driver=%{y}\u003cbr\u003eDuration (Seconds, Outliers\u002fRed Flags, Removed)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SAI","marker":{"color":"#EF1A2D"},"name":"SAI","notched":false,"offsetgroup":"SAI","orientation":"h","showlegend":true,"x":[88.375,82.6,83.006,82.43299999999999,82.629,82.572,82.434,82.303,82.025,81.715,81.938,82.175,82.205,82.487,82.62,89.93,81.811,81.602,81.931,81.471,81.531,81.458,81.243,81.078,81.457,81.44,81.489,81.623,81.282,81.205,81.495,81.717,81.721,82.018,81.971,81.412,81.554,81.443,87.215,80.73,80.767,80.223,80.374,80.203,80.031,80.281,80.45,80.083,80.209,80.615,80.582,80.753,81.098,80.882],"x0":" ","xaxis":"x","y":["SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI","SAI"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Driver=%{y}\u003cbr\u003eDuration (Seconds, Outliers\u002fRed Flags, Removed)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"NOR","marker":{"color":"#FF8000"},"name":"NOR","notched":false,"offsetgroup":"NOR","orientation":"h","showlegend":true,"x":[89.78399999999999,83.18299999999999,82.656,82.60900000000001,82.685,82.632,82.744,82.63,82.727,82.695,82.936,82.814,83.15299999999999,88.205,81.936,87.418,82.356,81.642,81.907,81.749,81.745,81.562,81.713,81.611,81.976,81.837,81.864,81.982,81.848,81.574,81.69200000000001,81.769,81.51,81.446,81.662,81.518,81.901,86.576,81.025,80.652,80.613,80.62,79.971,80.188,80.26,79.91499999999999,80.151,80.261,79.959,80.267,80.107,80.294,80.481,80.571],"x0":" ","xaxis":"x","y":["NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR","NOR"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Driver=%{y}\u003cbr\u003eDuration (Seconds, Outliers\u002fRed Flags, Removed)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"LEC","marker":{"color":"#EF1A2D"},"name":"LEC","notched":false,"offsetgroup":"LEC","orientation":"h","showlegend":true,"x":[90.52,83.014,82.776,82.519,82.632,82.673,82.684,82.983,87.861,82.64699999999999,81.84100000000001,82.22200000000001,81.952,81.735,82.247,88.896,81.881,81.885,82.05799999999999,81.72200000000001,81.932,81.852,81.951,82.042,81.822,81.969,82.43299999999999,82.28399999999999,81.996,81.84100000000001,82.02199999999999,87.951,81.94200000000001,80.688,80.949,80.90899999999999,80.953,80.675,80.849,80.85300000000001,80.56,80.408,80.76,79.999,80.349,80 ...

# %%
def multi_lap_plot(names, addAll = True):
    fig = go.Figure()

    fig = px.line(lap_driver_no, x="lap", y="duration", color='Driver', labels={
    "duration": "Lap Time (In seconds, Outliers/Red Flags Removed)",
    "lap": "Lap"
}, title='Lap Times', color_discrete_map=color_map)
    fig.update_layout(title_text='<b>Lap Times</b>', titlefont = dict(
         family = 'Arial, sans-serif',
         size = 30
      ), title_x=0.5)

    button_all = dict(label = 'All',
                      method = 'update',
                      args = [{'visible': [True]*len(names),
                               'title': 'All',
                               'showlegend':True}])

    def create_layout_button(column):
        return dict(label = column,
                    method = 'update',
                    args = [{'visible': [c == column for c in names],
                             'title': column,
                             'showlegend': True}])

    fig.update_layout(
        updatemenus=[go.layout.Updatemenu(
            active = 0,
            buttons = ([button_all] * addAll) + [create_layout_button(column) for column in names]
            )
        ])

    fig.show()



def multi_pos_plot(names, addAll = True):
    fig = go.Figure()

    fig = px.line(lap_driver, x="lap", y="position", color='Driver', labels={
    "position":  "Position",
    "lap": "Lap"
}, color_discrete_map=color_map)
    fig.update_layout(title_text='<b>Position By Lap</b>', titlefont = dict(
         family = 'Arial, sans-serif',
         size = 30
      ), title_x=0.5)

    button_all = dict(label = 'All',
                      method = 'update',
                      args = [{'visible': [True]*len(names),
                               'title': 'All',
                               'showlegend':True}])

    def create_layout_button(column):
        return dict(label = column,
                    method = 'update',
                    args = [{'visible': [c == column for c in names],
                             'title': column,
                             'showlegend': True}])

    fig.update_layout(
        updatemenus=[go.layout.Updatemenu(
            active = 0,
            buttons = ([button_all] * addAll) + [create_layout_button(column) for column in names]
            )
        ])

    fig.show()

# %%
# if not lap_tim_emp:
#     multi_lap_plot(mapping)

# %%
if not lap_tim_emp:
    multi_pos_plot(mapping)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-1f8cc6534fc0> in <cell line: 1>()
#       1 if not lap_tim_emp:
# ----> 2     multi_pos_plot(mapping)
#
# NameError: name 'mapping' is not defined

# %%
drive_stand = driver_standings.merge(drivers_full, on='driverID', how='left', suffixes=('_1', '_2'))
drive_stand['points'] = drive_stand.points.astype(float)
drive_stand_race  = drive_stand .sort_values(by='points', ascending=False)
drive_stand_race[['Driver', 'points']].style.pipe(driver_stand)
# Out:
# <ipython-input-13-956f3cd6c2f3>:25: FutureWarning:
#
# this method is deprecated in favour of `Styler.hide(axis="index")`
# <style type="text/css">
# #T_fe06a_row0_col1, #T_fe06a_row1_col1, #T_fe06a_row2_col1, #T_fe06a_row3_col1, #T_fe06a_row4_col1, #T_fe06a_row5_col1, #T_fe06a_row6_col1, #T_fe06a_row7_col1, #T_fe06a_row8_col1, #T_fe06a_row9_col1, #T_fe06a_row10_col1, #T_fe06a_row11_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_fe06a_row12_col1 {
#   background-color: #40b5c4;
#   color: #f1f1f1;
# }
# #T_fe06a_row13_col1, #T_fe06a_row14_col1, #T_fe06a_row15_col1, #T_fe06a_row16_col1, #T_fe06a_row17_col1, #T_fe06a_row18_col1, #T_fe06a_row19_col1, #T_fe06a_row20_col1 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# </style>
# <table id="T_fe06a" class="dataframe">
#   <caption>Driver Standings</caption>
#   <thead>
#     <tr>
#       <th id="T_fe06a_level0_col0" class="col_heading level0 col0" >Driver</th>
#       <th id="T_fe06a_level0_col1" class="col_heading level0 col1" >points</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fe06a_row0_col0" class="data row0 col0" >VER</td>
#       <td id="T_fe06a_row0_col1" class="data row0 col1" >51.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row1_col0" class="data row1 col0" >LEC</td>
#       <td id="T_fe06a_row1_col1" class="data row1 col1" >47.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row2_col0" class="data row2 col0" >PER</td>
#       <td id="T_fe06a_row2_col1" class="data row2 col1" >46.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row3_col0" class="data row3 col0" >SAI</td>
#       <td id="T_fe06a_row3_col1" class="data row3 col1" >40.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row4_col0" class="data row4 col0" >PIA</td>
#       <td id="T_fe06a_row4_col1" class="data row4 col1" >28.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row5_col0" class="data row5 col0" >NOR</td>
#       <td id="T_fe06a_row5_col1" class="data row5 col1" >27.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row6_col0" class="data row6 col0" >RUS</td>
#       <td id="T_fe06a_row6_col1" class="data row6 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row7_col0" class="data row7 col0" >ALO</td>
#       <td id="T_fe06a_row7_col1" class="data row7 col1" >16.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row8_col0" class="data row8 col0" >STR</td>
#       <td id="T_fe06a_row8_col1" class="data row8 col1" >9.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row9_col0" class="data row9 col0" >HAM</td>
#       <td id="T_fe06a_row9_col1" class="data row9 col1" >8.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_fe06a_row10_col1" class="data row10 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row11_col0" class="data row11 col0" >TSU</td>
#       <td id="T_fe06a_row11_col1" class="data row11 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row12_col0" class="data row12 col0" >HUL</td>
#       <td id="T_fe06a_row12_col1" class="data row12 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row13_col0" class="data row13 col0" >MAG</td>
#       <td id="T_fe06a_row13_col1" class="data row13 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row14_col0" class="data row14 col0" >ALB</td>
#       <td id="T_fe06a_row14_col1" class="data row14 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row15_col0" class="data row15 col0" >ZHO</td>
#       <td id="T_fe06a_row15_col1" class="data row15 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row16_col0" class="data row16 col0" >RIC</td>
#       <td id="T_fe06a_row16_col1" class="data row16 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row17_col0" class="data row17 col0" >OCO</td>
#       <td id="T_fe06a_row17_col1" class="data row17 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row18_col0" class="data row18 col0" >GAS</td>
#       <td id="T_fe06a_row18_col1" class="data row18 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row19_col0" class="data row19 col0" >BOT</td>
#       <td id="T_fe06a_row19_col1" class="data row19 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_fe06a_row20_col0" class="data row20 col0" >SAR</td>
#       <td id="T_fe06a_row20_col1" class="data row20 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
const_stand_race = constructor_overall.sort_values(by='points', ascending=False)
const_stand_race[['name', 'points', 'wins']].style.pipe(const_standings)
# Out:
# <ipython-input-13-956f3cd6c2f3>:31: FutureWarning:
#
# this method is deprecated in favour of `Styler.hide(axis="index")`
# <style type="text/css">
# #T_4904b_row0_col1, #T_4904b_row1_col1, #T_4904b_row2_col1, #T_4904b_row3_col1, #T_4904b_row4_col1, #T_4904b_row5_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_4904b_row6_col1 {
#   background-color: #e2191c;
#   color: #f1f1f1;
# }
# #T_4904b_row7_col1, #T_4904b_row8_col1, #T_4904b_row9_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_4904b" class="dataframe">
#   <caption>Constructor Standings</caption>
#   <thead>
#     <tr>
#       <th id="T_4904b_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_4904b_level0_col1" class="col_heading level0 col1" >points</th>
#       <th id="T_4904b_level0_col2" class="col_heading level0 col2" >wins</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4904b_row0_col0" class="data row0 col0" >Red Bull</td>
#       <td id="T_4904b_row0_col1" class="data row0 col1" >97.000000</td>
#       <td id="T_4904b_row0_col2" class="data row0 col2" >2</td>
#     </tr>
#     <tr>
#       <td id="T_4904b_row1_col0" class="data row1 col0" >Ferrari</td>
#       <td id="T_4904b_row1_col1" class="data row1 col1" >93.000000</td>
#       <td id="T_4904b_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_4904b_row2_col0" class="data row2 col0" >McLaren</td>
#       <td id="T_4904b_row2_col1" class="data row2 col1" >55.000000</td>
#       <td id="T_4904b_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#     <tr>
#       <td id="T_4904b_row3_col0" class="data row3 col0" >Mercedes</td>
#       <td id="T_4904b_row3_col1" class="data row3 col1" >26.000000</td>
#       <td id="T_4904b_row3_col2" class="data row3 col2" >0</td>
#     </tr>
#     <tr>
#       <td id="T_4904b_row4_col0" class="data row4 col0" >Aston Martin</td>
#       <td id="T_4904b_row4_col1" class="data row4 col1" >25.000000</td>
#       <td id="T_4904b_row4_col2" class="data row4 col2" >0</td>
#     </tr>
#     <tr>
#       <td id="T_4904b_row5_col0" class="data row5 col0" >RB F1 Team</td>
#       <td id="T_4904b_row5_col1" class="data row5 col1" >6.000000</td>
#       <td id="T_4904b_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#     <tr>
#       <td id="T_4904b_row6_col0" class="data row6 col0" >Haas F1 Team</td>
#       <td id="T_4904b_row6_col1" class="data row6 col1" >4.000000</td>
#       <td id="T_4904b_row6_col2" class="data row6 col2" >0</td>
#     </tr>
#     <tr>
#       <td id="T_4904b_row7_col0" class="data row7 col0" >Williams</td>
#       <td id="T_4904b_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_4904b_row7_col2" class="data row7 col2" >0</td>
#     </tr>
#     <tr>
#       <td id="T_4904b_row8_col0" class="data row8 col0" >Sauber</td>
#       <td id="T_4904b_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_4904b_row8_col2" class="data row8 col2" >0</td>
#     </tr>
#     <tr>
#       <td id="T_4904b_row9_col0" class="data row9 col0" >Alpine F1 Team</td>
#       <td id="T_4904b_row9_col1" class="data row9 col1" >0.000000</td>
#       <td id="T_4904b_row9_col2" class="data row9 col2" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = go.Figure()

fig = px.line(constructor_results, x="race", y="points", color='name', labels={
    "points": "Points",
    "race": "Race"
}, title='Lap Times', color_discrete_map=constructor_color_map)
fig.update_layout(title_text='<b>Constructor Championship Timeline</b>', titlefont = dict(
         family = 'Arial, sans-serif',
         size = 30
      ), title_x=0.5)
fig.update_layout(xaxis_range=[1,24])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="65ea4d3e-025c-43ff-b9ac-a52fd30b1d3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65ea4d3e-025c-43ff-b9ac-a52fd30b1d3b")) {                    Plotly.newPlot(                        "65ea4d3e-025c-43ff-b9ac-a52fd30b1d3b",                        [{"hovertemplate":"name=Red Bull\u003cbr\u003eRace=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Red Bull","line":{"color":"#000B8D","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Red Bull","orientation":"v","showlegend":true,"x":[1,2,3],"xaxis":"x","y":[44.0,87.0,97.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Ferrari\u003cbr\u003eRace=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ferrari","line":{"color":"#EF1A2D","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Ferrari","orientation":"v","showlegend":true,"x":[1,2,3],"xaxis":"x","y":[27.0,49.0,93.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Mercedes\u003cbr\u003eRace=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mercedes","line":{"color":"#00A19B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mercedes","orientation":"v","showlegend":true,"x":[1,2,3],"xaxis":"x","y":[16.0,26.0,26.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=McLaren\u003cbr\u003eRace=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"McLaren","line":{"color":"#FF8000","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"McLaren","orientation":"v","showlegend":true,"x":[1,2,3],"xaxis":"x","y":[12.0,28.0,55.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Aston Martin\u003cbr\u003eRace=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aston Martin","line":{"color":"#002420","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Aston Martin","orientation":"v","showlegend":true,"x":[1,2,3],"xaxis":"x","y":[3.0,13.0,25.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Sauber\u003cbr\u003eRace=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sauber","line":{"color":"#A42134","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Sauber","orientation":"v","showlegend":true,"x":[1,2,3],"xaxis":"x","y":[0.0,0.0,0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Haas F1 Team\u003cbr\u003eRace=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haas F1 Team","line":{"color":"#E6002B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Haas F1 Team","orientation":"v","showlegend":true,"x":[1,2,3],"xaxis":"x","y":[0.0,1.0,4.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=RB F1 Team\u003cbr\u003eRace=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RB F1 Team","line":{"color":"#20394C","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RB F1 Team","orientation":"v","showlegend":true,"x":[1,2,3],"xaxis":"x","y":[0.0,0.0,6.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Williams\u003cbr\u003eRace=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Williams","line":{"color":"#00A0DE","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Williams","orientation":"v","showlegend":true,"x":[1,2,3],"xaxis":"x","y":[0.0,0.0,0.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"name=Alpine F1 Team\u003cbr\u003eRace=%{x}\u003cbr\u003ePoints=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alpine F1 Team","line":{"color":"#2173B8 ...
